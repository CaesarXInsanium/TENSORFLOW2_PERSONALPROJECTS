# %%
import numpy as np
import cv2
import os
from PIL import Image
testing = True

if __name__ == '__main__' and testing:
    os.chdir(r'C:\Users\jesus\Pictures\Saved Pictures')
    image_list = os.listdir(os.getcwd())
    for image in image_list:
        try:
            loaded_image = Image.open(image)
            loaded_image.show()
        except:
            continue

# %%
np
# Out:
# <module 'numpy' from 'c:\\Users\\jesus\\Documents\\WorkFiles\\PythonCode\\TF2_personal_projects\\git_env\\lib\\site-packages\\numpy\\__init__.py'>

# %%
loaded_image = Image.open(os.listdir()[0])

# %%
loaded_image.size
# Out:
# (1201, 892)

# %%
array_image = np.asarray(loaded_image)

# %%
array_image.shape
# Out:
# (892, 1201, 4)

# %%
print(array_image)
# Out:
# [[[255 239  63 255]
#   [255 239  63 255]
#   [255 239  63 255]
#   ...
#   [223 223 223 255]
#   [223 223 223 255]
#   [223 223 223 255]]
#
#  [[255 237  61 255]
#   [255 237  61 255]
#   [255 237  61 255]
#   ...
#   [223 223 223 255]
#   [223 223 223 255]
#   [223 223 223 255]]
#
#  [[255 236  59 255]
#   [255 236  59 255]
#   [255 236  59 255]
#   ...
#   [223 223 223 255]
#   [223 223 223 255]
#   [223 223 223 255]]
#
#  ...
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]]

# %%
import tensorflow as tf

# %%
tf.convert_to_tensor(array_image)
# Out:
# <tf.Tensor: shape=(892, 1201, 4), dtype=uint8, numpy=
# array([[[255, 239,  63, 255],
#         [255, 239,  63, 255],
#         [255, 239,  63, 255],
#         ...,
#         [223, 223, 223, 255],
#         [223, 223, 223, 255],
#         [223, 223, 223, 255]],
#
#        [[255, 237,  61, 255],
#         [255, 237,  61, 255],
#         [255, 237,  61, 255],
#         ...,
#         [223, 223, 223, 255],
#         [223, 223, 223, 255],
#         [223, 223, 223, 255]],
#
#        [[255, 236,  59, 255],
#         [255, 236,  59, 255],
#         [255, 236,  59, 255],
#         ...,
#         [223, 223, 223, 255],
#         [223, 223, 223, 255],
#         [223, 223, 223, 255]],
#
#        ...,
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         ...,
#         [255, 255, 255, 255],
#         [255, 255, 255, 255],
#         [255, 255, 255, 255]],
#
#        [[255, 255, 255, 255],
#         [255, 255, 255, 255],
# ...

# %%
tf.convert_to_tensor(array_image) / 255
# Out:
# <tf.Tensor: shape=(892, 1201, 4), dtype=float32, numpy=
# array([[[1.        , 0.9372549 , 0.24705882, 1.        ],
#         [1.        , 0.9372549 , 0.24705882, 1.        ],
#         [1.        , 0.9372549 , 0.24705882, 1.        ],
#         ...,
#         [0.8745098 , 0.8745098 , 0.8745098 , 1.        ],
#         [0.8745098 , 0.8745098 , 0.8745098 , 1.        ],
#         [0.8745098 , 0.8745098 , 0.8745098 , 1.        ]],
#
#        [[1.        , 0.92941177, 0.23921569, 1.        ],
#         [1.        , 0.92941177, 0.23921569, 1.        ],
#         [1.        , 0.92941177, 0.23921569, 1.        ],
#         ...,
#         [0.8745098 , 0.8745098 , 0.8745098 , 1.        ],
#         [0.8745098 , 0.8745098 , 0.8745098 , 1.        ],
#         [0.8745098 , 0.8745098 , 0.8745098 , 1.        ]],
#
#        [[1.        , 0.9254902 , 0.23137255, 1.        ],
#         [1.        , 0.9254902 , 0.23137255, 1.        ],
#         [1.        , 0.9254902 , 0.23137255, 1.        ],
# ...

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras.preprocessing.image import load_img

# %%
import warnings

# %%
img = load_img(os.listdir()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-17d5e077d435> in <module>
# ----> 1 img = load_img(os.listdir()[0])
#
# NameError: name 'os' is not defined

# %%
import os

# %%
img = load_img(os.listdir()[0])
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-17d5e077d435> in <module>
# ----> 1 img = load_img(os.listdir()[0])
#
# c:\Users\jesus\Documents\WorkFiles\PythonCode\TF2_personal_projects\git_env\lib\site-packages\keras_preprocessing\image\utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     111         raise ImportError('Could not import PIL.Image. '
#     112                           'The use of `load_img` requires PIL.')
# --> 113     with open(path, 'rb') as f:
#     114         img = pil_image.open(io.BytesIO(f.read()))
#     115         if color_mode == 'grayscale':
#
# PermissionError: [Errno 13] Permission denied: '.ipynb_checkpoints'
